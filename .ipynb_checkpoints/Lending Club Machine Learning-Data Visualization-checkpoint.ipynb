# %% [markdown]
# # Lending Club Machine Learning: Data Visualization
#
# ### Can we build a machine learning model that can accurately predict if a borrower will pay off their loan on time or not?

# %% [markdown]
# Lending Club, a marketplace for personal loans that matches borrowers who are seeking a loan with investors looking to lend money and make a return. Each borrower fills out a comprehensive application, providing their past financial history, the reason for the loan, and more. Lending Club evaluates each borrower’s credit score using past historical data and their own data science process and then assigns an interest rate to the borrower.

# %% [markdown]
# Approved loans are listed on the Lending Club website, where qualified investors can browse recently approved loans, the borrower’s credit score, the purpose for the loan, and other information from the application.
#
# Once an investor decides to fund a loan, the borrower then makes monthly payments back to Lending Club. Lending Club redistributes these payments to investors.

# %% [markdown]
# # The Problem:
# Many loans aren’t completely paid off on time and some borrowers default on the loan.
#
# I have been tasked with building a model to predict whether borrowers are likely to pay or default on their loans.

# %% [markdown]
# # The Data:

# %% [markdown]
# On LendingClub’s site, you can select different year ranges to download data sets (in CSV format)
# for both approved and declined loans.

# %% [markdown]
# You’ll also find a data dictionary (in XLS format) towards the bottom of the LendingClub page, which contains information on the different column names. This data dictionary is useful for understanding what each column represents in the data set.
#
# The data dictionary contains two sheets:
#
# 1. LoanStats sheet: describes the approved loans dataset
# 2. RejectStats sheet: describes the rejected loans dataset

# %% [markdown]
# For this project I’ll be using the(LoanStats sheet) working with approved loans data for the years 2007 to 2011.
#
# The approved loans data set contains information on current loans, completed loans, and defaulted loans.

# %% [markdown]
# ![LendingClubDataDashboard.JPG](attachment:LendingClubDataDashboard.JPG)

# %% [markdown]
# # Loading The Data Into Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('max_columns', 120)
pd.set_option('max_colwidth', 5000)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import datetime
plt.rcParams['figure.figsize'] = (12,8)

# %% [markdown]
# # Tasks for Cleaning Data
#
# 1. Remove the first line: it contains extraneous text instead of the column titles. This text prevents the data set from being parsed properly by the pandas library.
# 2. Removing all columns with more than 50% missing values

# %%
#skip row 1 so pandas can parse the data properly.
loans_20072011 = pd.read_csv('data/lending_club_loans.csv', skiprows=1, low_memory=False)
half_count = len(loans_20072011) / 2
loans_20072011 = loans_20072011.dropna(thresh=half_count,axis=1) # Drop any column with more than 50% missing values
loans_20072011 = loans_20072011.drop(['desc'],axis=1) # These columns are not useful for our purposes

# %%
loans_20072011.head(3)
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  installment  \
# 0     5000.0       5000.0           4975.0   36 months   10.65%       162.87
# 1     2500.0       2500.0           2500.0   60 months   15.27%        59.83
# 2     2400.0       2400.0           2400.0   36 months   15.96%        84.33
#
#   grade sub_grade emp_title emp_length home_ownership  annual_inc  \
# 0     B        B2       NaN  10+ years           RENT     24000.0
# 1     C        C4     Ryder   < 1 year           RENT     30000.0
# 2     C        C5       NaN  10+ years           RENT     12252.0
#
#   verification_status   issue_d  loan_status pymnt_plan         purpose  \
# 0            Verified  Dec-2011   Fully Paid          n     credit_card
# 1     Source Verified  Dec-2011  Charged Off          n             car
# 2        Not Verified  Dec-2011   Fully Paid          n  small_business
#
#                   title zip_code addr_state    dti  delinq_2yrs  \
# 0              Computer    860xx         AZ  27.65          0.0
# 1                  bike    309xx         GA   1.00          0.0
# 2  real estate business    606xx         IL   8.72          0.0
#
#   earliest_cr_line  inq_last_6mths  open_acc  pub_rec  revol_bal revol_util  \
# 0         Jan-1985             1.0       3.0      0.0    13648.0      83.7%
# 1         Apr-1999             5.0       3.0      0.0     1687.0       9.4%
# 2         Nov-2001             2.0       2.0      0.0     2956.0      98.5%
#
#    total_acc initial_list_status  out_prncp  out_prncp_inv  total_pymnt  \
# 0        9.0                   f        0.0            0.0  5863.155187
# 1        4.0                   f        0.0            0.0  1014.530000
# 2       10.0                   f        0.0            0.0  3005.666844
#
#    total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 0          5833.84          5000.00         863.16                 0.0
# 1          1014.53           456.46         435.17                 0.0
# 2          3005.67          2400.00         605.67                 0.0
#
#    recoveries  collection_recovery_fee last_pymnt_d  last_pymnt_amnt  \
# 0         0.0                     0.00     Jan-2015           171.62
# 1       122.9                     1.11     Apr-2013           119.66
# 2         0.0                     0.00     Jun-2014           649.91
#
#   last_credit_pull_d  collections_12_mths_ex_med  policy_code  \
# 0           May-2019                         0.0          1.0
# 1           Oct-2016                         0.0          1.0
# 2           Jun-2017                         0.0          1.0
#
#   application_type  acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# 0       Individual             0.0                       0.0          0.0
# 1       Individual             0.0                       0.0          0.0
# 2       Individual             0.0                       0.0          0.0
#
#    pub_rec_bankruptcies  tax_liens hardship_flag debt_settlement_flag
# 0                   0.0        0.0             N                    N
# 1                   0.0        0.0             N                    N
# 2                   0.0        0.0             N                    N

# %%
loans_20072011.shape
# Out:
# (42538, 52)

# %%
#search for duplicate rows
loans_20072011.duplicated().value_counts()
# Out:
# False    42536
# True         2
# dtype: int64

# %%
loans_20072011 = loans_20072011.drop_duplicates()
print(loans_20072011.iloc[0])
print(loans_20072011.shape[1])
# Out:
# loan_amnt                            5000
# funded_amnt                          5000
# funded_amnt_inv                      4975
# term                            36 months
# int_rate                           10.65%
# installment                        162.87
# grade                                   B
# sub_grade                              B2
# emp_title                             NaN
# emp_length                      10+ years
# home_ownership                       RENT
# annual_inc                          24000
# verification_status              Verified
# issue_d                          Dec-2011
# loan_status                    Fully Paid
# pymnt_plan                              n
# purpose                       credit_card
# title                            Computer
# zip_code                            860xx
# addr_state                             AZ
# dti                                 27.65
# delinq_2yrs                             0
# earliest_cr_line                 Jan-1985
# inq_last_6mths                          1
# open_acc                                3
# pub_rec                                 0
# revol_bal                           13648
# revol_util                          83.7%
# total_acc                               9
# initial_list_status                     f
# out_prncp                               0
# out_prncp_inv                           0
# total_pymnt                       5863.16
# total_pymnt_inv                   5833.84
# total_rec_prncp                      5000
# total_rec_int                      863.16
# total_rec_late_fee                      0
# recoveries                              0
# collection_recovery_fee                 0
# last_pymnt_d                     Jan-2015
# last_pymnt_amnt                    171.62
# last_credit_pull_d               May-2019
# collections_12_mths_ex_med              0
# policy_code                             1
# application_type               Individual
# acc_now_delinq                          0
# chargeoff_within_12_mths                0
# delinq_amnt                             0
# pub_rec_bankruptcies                    0
# tax_liens                               0
# hardship_flag                           N
# debt_settlement_flag                    N
# Name: 0, dtype: object
# 52

# %%
#verify for duplicate rows removed
loans_20072011.duplicated().value_counts()
# Out:
# False    42536
# dtype: int64

# %% [markdown]
# # Data Visualizations

# %%
# Loan Status
plt.figure(figsize = (10,6))
g = sns.countplot(x="loan_status",data=loans_20072011,
                  palette='hls')
g.set_xticklabels(g.get_xticklabels(),rotation=45)
g.set_title("Loan Status", fontsize=20)
g.set_xlabel("Loan Status", fontsize=15)
g.set_ylabel("Loan Amount", fontsize=20)

plt.savefig("images/loanstatus.png")

# %%
# Bar plot of Term (Loan taken for number of months)
plt.figure(figsize=(10,6))
sns.barplot("term", "loan_amnt", data=loans_20072011, palette='hls')
plt.title("Term of Loan", fontsize=16)
plt.xlabel("Months", fontsize=14)
plt.ylabel("Loan Amount", fontsize=14)

plt.savefig("images/termofloan.png")

# %%
# Employment Length and Number of Loans
loans_20072011['emp_length'].value_counts().sort_values().plot(kind='barh',figsize=(18,8))
plt.title('Number of loans distributed by Employment Years',fontsize=20)
plt.xlabel('Number of loans',fontsize=15)
plt.ylabel('Years worked',fontsize=15);
plt.savefig("images/employmentlengthandnumberofloans.png")

# %%
df = pd.read_csv('data/lending_club_loans.csv', skiprows=1, low_memory=False)

# %%
# Create a target variable "Loan Status" with two categories Good and Bad Loan
df["Loan_Class"] = np.where((df.loan_status == 'Current') |
                        (df.loan_status == 'Fully Paid') |
                        (df.loan_status== "Issued") |
                        (df.loan_status == 'Does not meet the credit policy. Status:Fully Paid'), 1, 0)

# %%
# No of Defaulted Loans per State
fig = plt.figure(figsize=(18,10))
df[df['Loan_Class']==1].groupby('addr_state')['Loan_Class'].count().sort_values().plot(kind='barh')
plt.ylabel('State',fontsize=15)
plt.xlabel('Number Of Loans',fontsize=15)
plt.title('Number Of Defaulted Loans Per State',fontsize=20);

plt.savefig("images/numberofdefaultedloansperstate.png")

# %%
# Boxplot of Term and Loan Amount
print("Loan Amount Distribution BoxPlot")
plt.figure(figsize=(8,5))
sns.boxplot(x=loans_20072011.term, y=loans_20072011.loan_amnt)
plt.title("Loan Amount Distribution", fontsize=16)
plt.savefig("images/boxtermandloanamount.png")
# Out:
# Loan Amount Distribution BoxPlot

# %%
# Crosstabulation of Purpose and Loan Status
purp_loan= ['purpose', 'loan_status']
cm = sns.light_palette("green", as_cmap=True)
pd.crosstab(loans_20072011[purp_loan[0]], loans_20072011[purp_loan[1]]).style.background_gradient(cmap = cm)
#plt.savefig("images/crosstabulation.png")
# Out:
# <style  type="text/css" >
#     #T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col0 {
#             background-color:  #daf9da;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col1 {
#             background-color:  #dcfadc;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col2 {
#             background-color:  #d8f8d8;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col3 {
#             background-color:  #d3f5d3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col0 {
#             background-color:  #bae7ba;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col1 {
#             background-color:  #b0e2b0;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col2 {
#             background-color:  #99d599;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col3 {
#             background-color:  #a5dba5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col0 {
#             background-color:  #008000;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col1 {
#             background-color:  #008000;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col2 {
#             background-color:  #008000;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col3 {
#             background-color:  #008000;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row3_col0 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row3_col1 {
#             background-color:  #cdf2cd;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row3_col2 {
#             background-color:  #d3f5d3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row3_col3 {
#             background-color:  #e4fee4;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row4_col0 {
#             background-color:  #caf0ca;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row4_col1 {
#             background-color:  #afe1af;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row4_col2 {
#             background-color:  #bee9be;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row4_col3 {
#             background-color:  #c1ebc1;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row5_col0 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row5_col1 {
#             background-color:  #defbde;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row5_col2 {
#             background-color:  #ddfbdd;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row5_col3 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row6_col0 {
#             background-color:  #d5f6d5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row6_col1 {
#             background-color:  #d4f6d4;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row6_col2 {
#             background-color:  #caf0ca;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row6_col3 {
#             background-color:  #caf0ca;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row7_col0 {
#             background-color:  #defbde;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row7_col1 {
#             background-color:  #d5f6d5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row7_col2 {
#             background-color:  #dcfadc;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row7_col3 {
#             background-color:  #defbde;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row8_col0 {
#             background-color:  #e0fce0;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row8_col1 {
#             background-color:  #dbf9db;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row8_col2 {
#             background-color:  #ddfbdd;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row8_col3 {
#             background-color:  #e0fce0;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row9_col0 {
#             background-color:  #b2e3b2;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row9_col1 {
#             background-color:  #87cb87;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row9_col2 {
#             background-color:  #90d090;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row9_col3 {
#             background-color:  #b6e5b6;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row10_col0 {
#             background-color:  #e5ffe5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row10_col1 {
#             background-color:  #e5ffe5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row10_col2 {
#             background-color:  #e5ffe5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row10_col3 {
#             background-color:  #e5ffe5;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row11_col0 {
#             background-color:  #c0eac0;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row11_col1 {
#             background-color:  #aee0ae;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row11_col2 {
#             background-color:  #cdf2cd;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row11_col3 {
#             background-color:  #d3f5d3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row12_col0 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row12_col1 {
#             background-color:  #e2fde2;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row12_col2 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row12_col3 {
#             background-color:  #e3fee3;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row13_col0 {
#             background-color:  #dffcdf;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row13_col1 {
#             background-color:  #dcfadc;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row13_col2 {
#             background-color:  #daf9da;
#         }    #T_1b89169e_9b57_11e9_a481_00216beb53b0row13_col3 {
#             background-color:  #dbf9db;
#         }</style>
# <table id="T_1b89169e_9b57_11e9_a481_00216beb53b0" >
# <thead>    <tr>
#         <th class="index_name level0" >loan_status</th>
#         <th class="col_heading level0 col0" >Charged Off</th>
#         <th class="col_heading level0 col1" >Does not meet the credit policy. Status:Charged Off</th>
#         <th class="col_heading level0 col2" >Does not meet the credit policy. Status:Fully Paid</th>
#         <th class="col_heading level0 col3" >Fully Paid</th>
#     </tr>    <tr>
#         <th class="index_name level0" >purpose</th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_1b89169e_9b57_11e9_a481_00216beb53b0level0_row0" class="row_heading level0 row0" >car</th>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col0" class="data row0 col0" >160</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col1" class="data row0 col1" >13</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col2" class="data row0 col2" >51</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row0_col3" class="data row0 col3" >1391</td>
#     </tr>    <tr>
#         <th id="T_1b89169e_9b57_11e9_a481_00216beb53b0level0_row1" class="row_heading level0 row1" >credit_card</th>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col0" class="data row1 col0" >548</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col1" class="data row1 col1" >69</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col2" class="data row1 col2" >271</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row1_col3" class="data row1 col3" >4589</td>
#     </tr>    <tr>
#         <th id="T_1b89169e_9b57_11e9_a481_00216beb53b0level0_row2" class="row_heading level0 row2" >debt_consolidation</th>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col0" class="data row2 col0" >2792</td>
#         <td id="T_1b89169e_9b57_11e9_a481_00216beb53b0row2_col1" class="data row2 col1" >292</td>
#         <td id="T_1b89169e_9b57_11e9_a48
